# %% [markdown]
# # Create a Custom Transformer

# %%
import nltk
nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger'])
# Out:
# [nltk_data] Downloading package punkt to /home/mickie/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/mickie/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/mickie/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import re
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import FeatureUnion

# %%
url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'

# %% [markdown]
# ### Implement the StartingVerbExtractor class

# %%
class StartingVerbExtractor(BaseEstimator, TransformerMixin):

    def starting_verb(self, text):
        # tokenize by sentences
        sentence_list = nltk.sent_tokenize(text)
        print(sentence_list)
        for sentence in sentence_list:
            # tokenize each sentence into words and tag part of speech
            pos_tags = nltk.pos_tag(tokenize(sentence))
            print(pos_tags)
            print('\n')

            # index pos_tags to get the first word and part of speech tag
            first_word, first_tag = pos_tags[0]
            
            # return true if the first word is an appropriate verb or RT for retweet
            if first_tag in ['VB', 'VBP'] or first_word == 'RT':
                return True

            return False

    def fit(self, x, y=None):
        return self

    def transform(self, X):
        # apply starting_verb function to all values in X
        X_tagged = pd.Series(X).apply(self.starting_verb)

        return pd.DataFrame(X_tagged)

# %% [markdown]
# ### Run program to test

# %%
def load_data():
    df = pd.read_csv('corporate_messaging.csv', encoding='latin-1')
    df = df[(df["category:confidence"] == 1) & (df['category'] != 'Exclude')]
    X = df.text.values
    y = df.category.values
    return X, y


def tokenize(text):
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens


def model_pipeline():
    pipeline = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('vect', CountVectorizer(tokenizer=tokenize)),
                ('tfidf', TfidfTransformer())
            ])),

            ('starting_verb', StartingVerbExtractor())
        ])),

        ('clf', RandomForestClassifier())
    ])

    return pipeline


def display_results(y_test, y_pred):
    labels = np.unique(y_pred)
    confusion_mat = confusion_matrix(y_test, y_pred, labels=labels)
    accuracy = (y_pred == y_test).mean()

    print("Labels:", labels)
    print("Confusion Matrix:\n", confusion_mat)
    print("Accuracy:", accuracy)


def main():
    X, y = load_data()
    X_train, X_test, y_train, y_test = train_test_split(X, y)

    model = model_pipeline()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    display_results(y_test, y_pred)

main()
# Out:
# ['RT @wealthinsights: WSJ: Philanthropy as Enterprise http://ow.ly/Juyz']
# [('rt', 'NN'), ('@', 'JJ'), ('wealthinsights', 'NNS'), (':', ':'), ('wsj', 'NN'), (':', ':'), ('philanthropy', 'NN'), ('a', 'DT'), ('enterprise', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['In Mexico, Danone Semilla project plans to create 4,000 jobs in microdistribution by 2015 #social_innovation http://t.co/7oWctKhH']
# [('in', 'IN'), ('mexico', 'NN'), (',', ','), ('danone', 'NN'), ('semilla', 'NN'), ('project', 'NN'), ('plan', 'NN'), ('to', 'TO'), ('create', 'VB'), ('4,000', 'CD'), ('job', 'NN'), ('in', 'IN'), ('microdistribution', 'NN'), ('by', 'IN'), ('2015', 'CD'), ('#', '#'), ('social_innovation', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Corporate Responsibility at Merck: $23.8 million investment in partnerships to address underlying barriers to health.', '#BeWell']
# [('corporate', 'JJ'), ('responsibility', 'NN'), ('at', 'IN'), ('merck', 'NN'), (':', ':'), ('$', '$'), ('23.8', 'CD'), ('million', 'CD'), ('investment', 'NN'), ('in', 'IN'), ('partnership', 'NN'), ('to', 'TO'), ('address', 'VB'), ('underlying', 'VBG'), ('barrier', 'JJR'), ('to', 'TO'), ('health', 'NN'), ('.', '.')]
#
#
# ['Children surviving 5 yrs after a cancer diagnosis has grown from 58% in 1975 to 81% today #valueofmeds http://t.co/BiWNjmJs0n']
# [('children', 'NNS'), ('surviving', 'VBG'), ('5', 'CD'), ('yr', 'NN'), ('after', 'IN'), ('a', 'DT'), ('cancer', 'NN'), ('diagnosis', 'NN'), ('ha', 'VBD'), ('grown', 'VBN'), ('from', 'IN'), ('58', 'CD'), ('%', 'NN'), ('in', 'IN'), ('1975', 'CD'), ('to', 'TO'), ('81', 'CD'), ('%', 'NN'), ('today', 'NN'), ('#', '#'), ('valueofmeds', 'NNS'), ('urlplaceholder', 'VBP')]
#
#
# ['With #Citi IPB receive support through our exclusive partnerships with leading businesses.', 'Learn more here:åÊhttp://t.co/zolLWLJSnM #IPBEMEA']
# [('with', 'IN'), ('#', '#'), ('citi', 'JJ'), ('ipb', 'NN'), ('receive', 'JJ'), ('support', 'NN'), ('through', 'IN'), ('our', 'PRP$'), ('exclusive', 'JJ'), ('partnership', 'NN'), ('with', 'IN'), ('leading', 'VBG'), ('business', 'NN'), ('.', '.')]
#
#
# ['Designers and clients lose time due to the manual feedback loop.', '@conceptbox enables sharing and collaboration in real-time.', '#SeedcampLive']
# [('designers', 'NNS'), ('and', 'CC'), ('client', 'NN'), ('lose', 'JJ'), ('time', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('manual', 'JJ'), ('feedback', 'NN'), ('loop', 'NN'), ('.', '.')]
#
#
# ['Pfizer & Strides Arcolab to collaborate on generic products: www.pfizer.com']
# [('pfizer', 'NN'), ('&', 'CC'), ('strides', 'NNS'), ('arcolab', 'VBP'), ('to', 'TO'), ('collaborate', 'VB'), ('on', 'IN'), ('generic', 'JJ'), ('product', 'NN'), (':', ':'), ('www.pfizer.com', 'NN')]
#
#
# ['AMA Foundation Recognizes PFE for Excellence in Medicine partnership http://t.co/ZfQi4pYxw2']
# [('ama', 'NN'), ('foundation', 'NN'), ('recognizes', 'VBZ'), ('pfe', 'NN'), ('for', 'IN'), ('excellence', 'NN'), ('in', 'IN'), ('medicine', 'NN'), ('partnership', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Barclays Wealth has won 6 Euromoney Private Banking Awards including Best Overall Private Bank in the UK and in Jersey.', 'http://ow.ly/3Xn9W']
# [('barclays', 'NNS'), ('wealth', 'VBP'), ('ha', 'JJ'), ('won', 'VBD'), ('6', 'CD'), ('euromoney', 'JJ'), ('private', 'JJ'), ('banking', 'NN'), ('awards', 'NNS'), ('including', 'VBG'), ('best', 'JJS'), ('overall', 'JJ'), ('private', 'JJ'), ('bank', 'NN'), ('in', 'IN'), ('the', 'DT'), ('uk', 'NN'), ('and', 'CC'), ('in', 'IN'), ('jersey', 'NN'), ('.', '.')]
#
#
# ['Dr. Camidge to discuss activity of novel ALK-inhibitor Green Hall 1+2 12:30 CEST http://abstracts.webges.com/programme.php?congress=esmo2010']
# [('dr.', 'NN'), ('camidge', 'NN'), ('to', 'TO'), ('discus', 'VB'), ('activity', 'NN'), ('of', 'IN'), ('novel', 'JJ'), ('alk-inhibitor', 'NN'), ('green', 'JJ'), ('hall', 'NN'), ('1+2', 'CD'), ('12:30', 'CD'), ('cest', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['#HealthyBytes 7: A healthy lifestyle has never been so easy!', 'Watch the video and try it out!', 'http://t.co/3ioc2MwFZU']
# [('#', '#'), ('healthybytes', 'VBZ'), ('7', 'CD'), (':', ':'), ('a', 'DT'), ('healthy', 'JJ'), ('lifestyle', 'NN'), ('ha', 'NN'), ('never', 'RB'), ('been', 'VBN'), ('so', 'RB'), ('easy', 'JJ'), ('!', '.')]
#
#
# ['RT @ftadviser: Barclays and Standard Life tie-up for auto-enrolment http://t.co/PJnISdx1Hn']
# [('rt', 'NN'), ('@', 'NNP'), ('ftadviser', 'NN'), (':', ':'), ('barclays', 'NNS'), ('and', 'CC'), ('standard', 'JJ'), ('life', 'NN'), ('tie-up', 'NN'), ('for', 'IN'), ('auto-enrolment', 'JJ'), ('urlplaceholder', 'NN')]
#
#
# ['We continued to invest in R&amp D to enhance technologies for product development: http://t.co/rLlptQxZUq #Nestle 2012 http://t.co/8SoLv1OKJE']
# [('we', 'PRP'), ('continued', 'VBD'), ('to', 'TO'), ('invest', 'VB'), ('in', 'IN'), ('r', 'NN'), ('&', 'CC'), ('amp', 'NN'), ('d', 'NN'), ('to', 'TO'), ('enhance', 'VB'), ('technology', 'NN'), ('for', 'IN'), ('product', 'NN'), ('development', 'NN'), (':', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('nestle', 'JJ'), ('2012', 'CD'), ('urlplaceholder', 'NN')]
#
#
# ['Pfizer is pleased to partner with CytomX on a new oncology research collaboration http://t.co/IOqNXphISB']
# [('pfizer', 'NN'), ('is', 'VBZ'), ('pleased', 'JJ'), ('to', 'TO'), ('partner', 'NN'), ('with', 'IN'), ('cytomx', 'NN'), ('on', 'IN'), ('a', 'DT'), ('new', 'JJ'), ('oncology', 'NN'), ('research', 'NN'), ('collaboration', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['#2014 is the 10th anniversary of WISE: #Danone program to strengthen #safety attitudes in the company &amp  integrate them into labour practices']
# [('#', '#'), ('2014', 'CD'), ('is', 'VBZ'), ('the', 'DT'), ('10th', 'JJ'), ('anniversary', 'NN'), ('of', 'IN'), ('wise', 'NN'), (':', ':'), ('#', '#'), ('danone', 'NN'), ('program', 'NN'), ('to', 'TO'), ('strengthen', 'VB'), ('#', '#'), ('safety', 'NN'), ('attitude', 'NN'), ('in', 'IN'), ('the', 'DT'), ('company', 'NN'), ('&', 'CC'), ('amp', 'NN'), ('integrate', 'VBP'), ('them', 'PRP'), ('into', 'IN'), ('labour', 'NN'), ('practice', 'NN')]
#
#
# ['How can we improve math and science education?', 'Discuss with Adam Gilbert at Think Science Now http://bit.ly/dmTaUe']
# [('how', 'WRB'), ('can', 'MD'), ('we', 'PRP'), ('improve', 'VB'), ('math', 'NN'), ('and', 'CC'), ('science', 'NN'), ('education', 'NN'), ('?', '.')]
#
#
# ['Citi CEO Corbat: the time is right to pull together our resources, knowledge &amp  connectivity to achieve greater #financialinclusion  #FI2020']
# [('citi', 'NN'), ('ceo', 'NN'), ('corbat', 'NN'), (':', ':'), ('the', 'DT'), ('time', 'NN'), ('is', 'VBZ'), ('right', 'JJ'), ('to', 'TO'), ('pull', 'VB'), ('together', 'RB'), ('our', 'PRP$'), ('resource', 'NN'), (',', ','), ('knowledge', 'NN'), ('&', 'CC'), ('amp', 'NN'), ('connectivity', 'NN'), ('to', 'TO'), ('achieve', 'VB'), ('greater', 'JJR'), ('#', '#'), ('financialinclusion', 'NN'), ('#', '#'), ('fi2020', 'NN')]
#
#
# ['AFib is most common sustained cardiac arrhythmia, affecting approximately &gt  5M people in U.S. #ESCParis2011']
# [('afib', 'NN'), ('is', 'VBZ'), ('most', 'RBS'), ('common', 'JJ'), ('sustained', 'VBD'), ('cardiac', 'JJ'), ('arrhythmia', 'NN'), (',', ','), ('affecting', 'VBG'), ('approximately', 'RB'), ('&', 'CC'), ('gt', 'VB'), ('5m', 'CD'), ('people', 'NNS'), ('in', 'IN'), ('u.s.', 'JJ'), ('#', '#'), ('escparis2011', 'NN')]
#
#
# ["\x89ÛÏWe're going to put money into making young people more employable\x89Û\x9d - #Nestle UK's Fiona Kendrick: http://t.co/hS0ojeCkMP via @MontagueJones"]
# [('\x89ûïwe', 'NN'), ("'re", 'VBP'), ('going', 'VBG'), ('to', 'TO'), ('put', 'VB'), ('money', 'NN'), ('into', 'IN'), ('making', 'VBG'), ('young', 'JJ'), ('people', 'NNS'), ('more', 'RBR'), ('employable\x89û\x9d', 'JJ'), ('-', ':'), ('#', '#'), ('nestle', 'JJ'), ('uk', 'NN'), ("'s", 'POS'), ('fiona', 'JJ'), ('kendrick', 'NN'), (':', ':'), ('urlplaceholder', 'NN'), ('via', 'IN'), ('@', 'NNP'), ('montaguejones', 'NNS')]
#
#
# ["Paul Bulcke  Healthier kids perform better at school &amp are more productive as adults..It's a virtuous circle  http://t.co/LPWX4UHUCt #wef2014"]
# [('paul', 'NN'), ('bulcke', 'NN'), ('healthier', 'JJR'), ('kid', 'NN'), ('perform', 'NN'), ('better', 'RBR'), ('at', 'IN'), ('school', 'NN'), ('&', 'CC'), ('amp', 'NN'), ('are', 'VBP'), ('more', 'RBR'), ('productive', 'JJ'), ('a', 'DT'), ('adults..it', 'NN'), ("'s", 'POS'), ('a', 'DT'), ('virtuous', 'JJ'), ('circle', 'NN'), ('urlplaceholder', 'NN'), ('#', '#'), ('wef2014', 'NN')]
#
#
# ['Barclays Wealth Hosts Excellence Awards in Isle of Man http://ow.ly/D7Mr']
# [('barclays', 'NNS'), ('wealth', 'VBP'), ('hosts', 'NNS'), ('excellence', 'NN'), ('awards', 'NNS'), ('in', 'IN'), ('isle', 'NN'), ('of', 'IN'), ('man', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Tony Coyle from Pfizer\x89Ûªs CTI &amp  @Alliance4Lupus discuss how we\x89Ûªre co-funding research to develop therapies for patients w/lupus #P4C2013']
# [('tony', 'JJ'), ('coyle', 'NN'), ('from', 'IN'), ('pfizer\x89ûªs', 'NN'), ('cti', 'NN'), ('&', 'CC'), ('amp', 'NN'), ('@', 'NN'), ('alliance4lupus', 'NN'), ('discus', 'VB'), ('how', 'WRB'), ('we\x89ûªre', 'JJ'), ('co-funding', 'JJ'), ('research', 'NN'), ('to', 'TO'), ('develop', 'VB'), ('therapy', 'NN'), ('for', 'IN'), ('patient', 'JJ'), ('w/lupus', 'NN'), ('#', '#'), ('p4c2013', 'NN')]
#
#
# ["Francis Collins  If you're seeking to improve the economic status of a population, focusing on health is a wise move  #wef2014 @NIHDirector"]
# [('francis', 'NN'), ('collins', 'NNS'), ('if', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('seeking', 'VBG'), ('to', 'TO'), ('improve', 'VB'), ('the', 'DT'), ('economic', 'JJ'), ('status', 'NN'), ('of', 'IN'), ('a', 'DT'), ('population', 'NN'), (',', ','), ('focusing', 'VBG'), ('on', 'IN'), ('health', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('wise', 'JJ'), ('move', 'NN'), ('#', '#'), ('wef2014', 'NN'), ('@', 'NNP'), ('nihdirector', 'NN')]
#
#
# ['What non-U.S. cities are seen as hubs for innovation or start-up activity?', 'What can we learn from them?', '#ProgressMakers #Citi']
# [('what', 'WP'), ('non-u.s.', 'JJ'), ('city', 'NN'), ('are', 'VBP'), ('seen', 'VBN'), ('a', 'DT'), ('hub', 'NN'), ('for', 'IN'), ('innovation', 'NN'), ('or', 'CC'), ('start-up', 'JJ'), ('activity', 'NN'), ('?', '.')]
#
#
# ['Barclays Wealth Blog Communication breakdown?', '- Our usual stoicism has been tested somewhat these last two weeks.', 'We... http://t.co/xpzfQPsU']
# [('barclays', 'NNS'), ('wealth', 'VBP'), ('blog', 'NN'), ('communication', 'NN'), ('breakdown', 'NN'), ('?', '.')]
#
#
# ["NestlÌ© to buy Kraft Foods' frozen pizza business in US & Canada - will not bid for Cadbury - www.nestle.com"]
# [('nestlì©', 'NN'), ('to', 'TO'), ('buy', 'VB'), ('kraft', 'NNP'), ('foods', 'NNS'), ("'", 'POS'), ('frozen', 'JJ'), ('pizza', 'NN'), ('business', 'NN'), ('in', 'IN'), ('us', 'PRP'), ('&', 'CC'), ('canada', 'SYM'), ('-', ':'), ('will', 'MD'), ('not', 'RB'), ('bid', 'VB'), ('for', 'IN'), ('cadbury', 'NN'), ('-', ':'), ('www.nestle.com', 'NN')]
#
#
# ['A nationwide education initiative from our Winiary culinary brand in Poland is helping teenagers learn to cook: http://t.co/bLtaBJFX']
# [('a', 'DT'), ('nationwide', 'JJ'), ('education', 'NN'), ('initiative', 'NN'), ('from', 'IN'), ('our', 'PRP$'), ('winiary', 'JJ'), ('culinary', 'JJ'), ('brand', 'NN'), ('in', 'IN'), ('poland', 'NN'), ('is', 'VBZ'), ('helping', 'VBG'), ('teenager', 'NN'), ('learn', 'NN'), ('to', 'TO'), ('cook', 'VB'), (':', ':'), ('urlplaceholder', 'NN')]
#
#
# ['Gary Pelletier of Pfizer Helpful Answers participates in Town Hall with LATINO USA addressing cancer and the Latino community']
# [('gary', 'JJ'), ('pelletier', 'NN'), ('of', 'IN'), ('pfizer', 'NN'), ('helpful', 'JJ'), ('answers', 'NNS'), ('participates', 'NNS'), ('in', 'IN'), ('town', 'NN'), ('hall', 'NN'), ('with', 'IN'), ('latino', 'NN'), ('usa', 'JJ'), ('addressing', 'VBG'), ('cancer', 'NN'), ('and', 'CC'), ('the', 'DT'), ('latino', 'NN'), ('community', 'NN')]
#
#
# ['Ray Kerins, VP, WWC, will be speaking @ BDI\x89Ûªs upcoming Healthcare Social Communications Leadership Forum http://bit.ly/L7bos']
# [('ray', 'NN'), ('kerins', 'NNS'), (',', ','), ('vp', 'NN'), (',', ','), ('wwc', 'NN'), (',', ','), ('will', 'MD'), ('be', 'VB'), ('speaking', 'VBG'), ('@', 'JJ'), ('bdi\x89ûªs', 'NN'), ('upcoming', 'VBG'), ('healthcare', 'JJ'), ('social', 'JJ'), ('communications', 'NNS'), ('leadership', 'NN'), ('forum', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['35 million Brazilians have climbed out of poverty over the last decade and 53% now belong to the middle class: http://t.co/yhwtmFpx']
# [('35', 'CD'), ('million', 'CD'), ('brazilians', 'NNS'), ('have', 'VBP'), ('climbed', 'VBN'), ('out', 'IN'), ('of', 'IN'), ('poverty', 'NN'), ('over', 'IN'), ('the', 'DT'), ('last', 'JJ'), ('decade', 'NN'), ('and', 'CC'), ('53', 'CD'), ('%', 'NN'), ('now', 'RB'), ('belong', 'RB'), ('to', 'TO'), ('the', 'DT'), ('middle', 'JJ'), ('class', 'NN'), (':', ':'), ('urlplaceholder', 'NN')]
#
#
# ['#Asthma causes kids to miss 13M+ school days a year.', 'Let\x89Ûªs work together to reduce that number.']
# [('#', '#'), ('asthma', 'NN'), ('cause', 'NN'), ('kid', 'NN'), ('to', 'TO'), ('miss', 'VB'), ('13m+', 'CD'), ('school', 'NN'), ('day', 'NN'), ('a', 'DT'), ('year', 'NN'), ('.', '.')]
#
#
# ['#Citi receives 2014 Community Reinvestment Award for Texas college savings program w/ @RAISETexas http://t.co/IRp11td4JQ']
# [('#', '#'), ('citi', 'NN'), ('receives', 'NNS'), ('2014', 'CD'), ('community', 'NN'), ('reinvestment', 'NN'), ('award', 'NN'), ('for', 'IN'), ('texas', 'JJ'), ('college', 'NN'), ('saving', 'VBG'), ('program', 'NN'), ('w/', 'NN'), ('@', 'NNP'), ('raisetexas', 'NN'), ('urlplaceholder', 'NN')]
#
#
# [' The important thing is to commit to eradicate child labour with an annual target and transparent reporting,  says Auret van Heerden, FLA.']
# [('the', 'DT'), ('important', 'JJ'), ('thing', 'NN'), ('is', 'VBZ'), ('to', 'TO'), ('commit', 'VB'), ('to', 'TO'), ('eradicate', 'VB'), ('child', 'VB'), ('labour', 'NN'), ('with', 'IN'), ('an', 'DT'), ('annual', 'JJ'), ('target', 'NN'), ('and', 'CC'), ('transparent', 'JJ'), ('reporting', 'NN'), (',', ','), ('say', 'VBP'), ('auret', 'JJ'), ('van', 'NN'), ('heerden', 'NN'), (',', ','), ('fla', 'NN'), ('.', '.')]
#
#
# ['Corporate Responsibility at Merck: Recycled or reused 3.3 billion gallons of water.', '#BeWell']
# [('corporate', 'JJ'), ('responsibility', 'NN'), ('at', 'IN'), ('merck', 'NN'), (':', ':'), ('recycled', 'VBD'), ('or', 'CC'), ('reused', 'VBD'), ('3.3', 'CD'), ('billion', 'CD'), ('gallon', 'NN'), ('of', 'IN'), ('water', 'NN'), ('.', '.')]
#
#
# ['Thank you!', 'RT @HectorValenciaa +2450 #CitiVolunteers gathered @Citi #ElSalvador , ready to revitalized 9 schools along the country']
# [('thank', 'NN'), ('you', 'PRP'), ('!', '.')]
#
#
# ['Our study also suggested that helping to prepare meals increased positive emotion &amp  pride.', '#HealthyKids http://t.co/CDpS10Byph']
# [('our', 'PRP$'), ('study', 'NN'), ('also', 'RB'), ('suggested', 'VBD'), ('that', 'IN'), ('helping', 'VBG'), ('to', 'TO'), ('prepare', 'VB'), ('meal', 'NN'), ('increased', 'JJ'), ('positive', 'JJ'), ('emotion', 'NN'), ('&', 'CC'), ('amp', 'JJ'), ('pride', 'NN'), ('.', '.')]
#
#
# ['PFE was proud to sponsor two panels highlighting the importance of preventive measures as part of healthy aging @IAGG2013']
# [('pfe', 'NN'), ('wa', 'NN'), ('proud', 'NN'), ('to', 'TO'), ('sponsor', 'VB'), ('two', 'CD'), ('panel', 'NN'), ('highlighting', 'VBG'), ('the', 'DT'), ('importance', 'NN'), ('of', 'IN'), ('preventive', 'JJ'), ('measure', 'NN'), ('a', 'DT'), ('part', 'NN'), ('of', 'IN'), ('healthy', 'JJ'), ('aging', 'VBG'), ('@', 'JJ'), ('iagg2013', 'NN')]
#
#
# ['Banks can help to stop human trafficking-Manhattan prosecutor:  http://t.co/OQGlbQH42t #Citigroup #BRK']
# [('banks', 'NNS'), ('can', 'MD'), ('help', 'VB'), ('to', 'TO'), ('stop', 'VB'), ('human', 'JJ'), ('trafficking-manhattan', 'JJ'), ('prosecutor', 'NN'), (':', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('citigroup', 'NN'), ('#', '#'), ('brk', 'NN')]
#
#
# ['RT WSJ Wealth Report Do the Rich Work Less as Their Taxes Increase?', 'http://t.co/3tKQxy6d']
# [('rt', 'NN'), ('wsj', 'WRB'), ('wealth', 'NN'), ('report', 'NN'), ('do', 'VBP'), ('the', 'DT'), ('rich', 'JJ'), ('work', 'NN'), ('less', 'RBR'), ('a', 'DT'), ('their', 'PRP$'), ('taxes', 'NNS'), ('increase', 'VB'), ('?', '.')]
#
#
# ['NestlÌ© Italia have been working with farmers to optimise water use in tomato production.', 'Watch our video for more: http://bit.ly/cuQFJr']
# [('nestlì©', 'RB'), ('italia', 'NNS'), ('have', 'VBP'), ('been', 'VBN'), ('working', 'VBG'), ('with', 'IN'), ('farmer', 'NN'), ('to', 'TO'), ('optimise', 'VB'), ('water', 'NN'), ('use', 'NN'), ('in', 'IN'), ('tomato', 'NN'), ('production', 'NN'), ('.', '.')]
#
#
# ['BW  wins Best Leadership Team in Global Private Banking in Geneva sponsored by The Banker & Professional Wealth Management magazines']
# [('bw', 'NN'), ('win', 'NN'), ('best', 'JJS'), ('leadership', 'NN'), ('team', 'NN'), ('in', 'IN'), ('global', 'JJ'), ('private', 'JJ'), ('banking', 'NN'), ('in', 'IN'), ('geneva', 'NN'), ('sponsored', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('banker', 'NN'), ('&', 'CC'), ('professional', 'JJ'), ('wealth', 'NN'), ('management', 'NN'), ('magazine', 'NN')]
#
#
# ['RT WSJ Wealth Report Did The Rich Get Rich From Hard Work or ?Connections?', '?', 'http://t.co/wwKijiMZ']
# [('rt', 'NN'), ('wsj', 'WRB'), ('wealth', 'NN'), ('report', 'NN'), ('did', 'VBD'), ('the', 'DT'), ('rich', 'JJ'), ('get', 'NN'), ('rich', 'JJ'), ('from', 'IN'), ('hard', 'JJ'), ('work', 'NN'), ('or', 'CC'), ('?', '.'), ('connections', 'NNS'), ('?', '.')]
#
#
# ['We help #ruralwomen dairy farmers in India increase production&amp produce higher-quality milk through targeted education http://t.co/alHpAzKzUi']
# [('we', 'PRP'), ('help', 'VBP'), ('#', '#'), ('ruralwomen', 'NNS'), ('dairy', 'VBP'), ('farmer', 'NN'), ('in', 'IN'), ('india', 'JJ'), ('increase', 'NN'), ('production', 'NN'), ('&', 'CC'), ('amp', 'JJ'), ('produce', 'NN'), ('higher-quality', 'NN'), ('milk', 'NN'), ('through', 'IN'), ('targeted', 'VBN'), ('education', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ["Barbara Rolls  Diet and exercise are needed for your general health, we're not just talking about obesity.", '#NINS2013']
# [('barbara', 'NN'), ('rolls', 'NNS'), ('diet', 'JJ'), ('and', 'CC'), ('exercise', 'NN'), ('are', 'VBP'), ('needed', 'VBN'), ('for', 'IN'), ('your', 'PRP$'), ('general', 'JJ'), ('health', 'NN'), (',', ','), ('we', 'PRP'), ("'re", 'VBP'), ('not', 'RB'), ('just', 'RB'), ('talking', 'VBG'), ('about', 'IN'), ('obesity', 'NN'), ('.', '.')]
#
#
# ['NestlÌ© Italy wins award for youth employment initiative: http://t.co/S8w8Od8ULU #employment4youth http://t.co/9gvomLY327']
# [('nestlì©', 'JJ'), ('italy', 'NN'), ('win', 'VBP'), ('award', 'NN'), ('for', 'IN'), ('youth', 'JJ'), ('employment', 'NN'), ('initiative', 'NN'), (':', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('employment4youth', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Danone Spain has managed to create over 150 job opportunities for Social School for Women Empowerment project #EndVAW']
# [('danone', 'NN'), ('spain', 'NN'), ('ha', 'NN'), ('managed', 'VBD'), ('to', 'TO'), ('create', 'VB'), ('over', 'IN'), ('150', 'CD'), ('job', 'NN'), ('opportunity', 'NN'), ('for', 'IN'), ('social', 'JJ'), ('school', 'NN'), ('for', 'IN'), ('women', 'NNS'), ('empowerment', 'JJ'), ('project', 'NN'), ('#', '#'), ('endvaw', 'NN')]
#
#
# ['#Danone and @Ashoka  Pemulung Empowerment Program  to improve living conditions of the waste pickers in Indonesia :http://t.co/mwhD9eFE']
# [('#', '#'), ('danone', 'NN'), ('and', 'CC'), ('@', 'NNP'), ('ashoka', 'VBP'), ('pemulung', 'JJ'), ('empowerment', 'JJ'), ('program', 'NN'), ('to', 'TO'), ('improve', 'VB'), ('living', 'VBG'), ('condition', 'NN'), ('of', 'IN'), ('the', 'DT'), ('waste', 'NN'), ('picker', 'NN'), ('in', 'IN'), ('indonesia', 'NN'), (':', ':'), ('urlplaceholder', 'NN')]
#
#
# ['Merck Fdn proud to support #mhealth texts/apps study improving diabetes outcomes.', 'Learn more: http://t.co/tX8jSXa8qQ  via @Health_Affairs']
# [('merck', 'NN'), ('fdn', 'NN'), ('proud', 'NN'), ('to', 'TO'), ('support', 'VB'), ('#', '#'), ('mhealth', 'NN'), ('texts/apps', 'NN'), ('study', 'NN'), ('improving', 'VBG'), ('diabetes', 'VBZ'), ('outcome', 'NN'), ('.', '.')]
#
#
# ['Listen to the final Q&A session of our Investor Seminar with CEO Paul Bulcke and CFO James Singh http://bit.ly/l4GbIt #Nestle #NestleIR']
# [('listen', 'NN'), ('to', 'TO'), ('the', 'DT'), ('final', 'JJ'), ('q', 'NN'), ('&', 'CC'), ('a', 'DT'), ('session', 'NN'), ('of', 'IN'), ('our', 'PRP$'), ('investor', 'NN'), ('seminar', 'NN'), ('with', 'IN'), ('ceo', 'NN'), ('paul', 'NN'), ('bulcke', 'NN'), ('and', 'CC'), ('cfo', 'NN'), ('james', 'NNS'), ('singh', 'JJ'), ('urlplaceholder', 'JJ'), ('#', '#'), ('nestle', 'JJ'), ('#', '#'), ('nestleir', 'NN')]
#
#
# ['Wealthy becoming increasingly active philanthropists despite downturn http://bit.ly/jgFqG']
# [('wealthy', 'JJ'), ('becoming', 'VBG'), ('increasingly', 'RB'), ('active', 'JJ'), ('philanthropist', 'NN'), ('despite', 'IN'), ('downturn', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ["Gluckman  We've not thought enough about how you wean children to have optimal taste and food preferences.", '#NINS2013']
# [('gluckman', 'NN'), ('we', 'PRP'), ("'ve", 'VBP'), ('not', 'RB'), ('thought', 'VBN'), ('enough', 'RB'), ('about', 'IN'), ('how', 'WRB'), ('you', 'PRP'), ('wean', 'VBP'), ('child', 'VB'), ('to', 'TO'), ('have', 'VB'), ('optimal', 'JJ'), ('taste', 'NN'), ('and', 'CC'), ('food', 'NN'), ('preference', 'NN'), ('.', '.')]
#
#
# ['Our very own Adam Schechter in action, helping deliver essential health supplies more quickly &amp  efficiently.', '#GBCH13 http://t.co/4YLxBAIgHz']
# [('our', 'PRP$'), ('very', 'RB'), ('own', 'JJ'), ('adam', 'NN'), ('schechter', 'NN'), ('in', 'IN'), ('action', 'NN'), (',', ','), ('helping', 'VBG'), ('deliver', 'RB'), ('essential', 'JJ'), ('health', 'NN'), ('supply', 'NN'), ('more', 'RBR'), ('quickly', 'RB'), ('&', 'CC'), ('amp', 'VB'), ('efficiently', 'RB'), ('.', '.')]
#
#
# ['In 2011 #Danone and the IUF signed the first ww agreement on health, safety, working conditions and stress: http://t.co/2YNJiLPg #people']
# [('in', 'IN'), ('2011', 'CD'), ('#', '#'), ('danone', 'NN'), ('and', 'CC'), ('the', 'DT'), ('iuf', 'NN'), ('signed', 'VBD'), ('the', 'DT'), ('first', 'JJ'), ('ww', 'NN'), ('agreement', 'NN'), ('on', 'IN'), ('health', 'NN'), (',', ','), ('safety', 'NN'), (',', ','), ('working', 'VBG'), ('condition', 'NN'), ('and', 'CC'), ('stress', 'NN'), (':', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('people', 'NNS')]
#
#
# ['Water Resources Review program conducted at 100 of our sites to date and invested in water-saving and cleaning programs during the year.']
# [('water', 'NN'), ('resources', 'NNS'), ('review', 'VBP'), ('program', 'NN'), ('conducted', 'VBN'), ('at', 'IN'), ('100', 'CD'), ('of', 'IN'), ('our', 'PRP$'), ('site', 'NN'), ('to', 'TO'), ('date', 'NN'), ('and', 'CC'), ('invested', 'VBN'), ('in', 'IN'), ('water-saving', 'NN'), ('and', 'CC'), ('cleaning', 'VBG'), ('program', 'NN'), ('during', 'IN'), ('the', 'DT'), ('year', 'NN'), ('.', '.')]
#
#
# ['Semilla Project has created a Social Development Institute to provide training to women in need and an access to jobs #DanoneEcosysteme']
# [('semilla', 'NN'), ('project', 'NN'), ('ha', 'NN'), ('created', 'VBD'), ('a', 'DT'), ('social', 'JJ'), ('development', 'NN'), ('institute', 'NN'), ('to', 'TO'), ('provide', 'VB'), ('training', 'NN'), ('to', 'TO'), ('woman', 'NN'), ('in', 'IN'), ('need', 'NN'), ('and', 'CC'), ('an', 'DT'), ('access', 'NN'), ('to', 'TO'), ('job', 'NN'), ('#', '#'), ('danoneecosysteme', 'NN')]
#
#
# ['15 million Americans suffer from depression.', 'Freda Lewis-Hall MD discusses the condition on @TheDoctors.', 'http://t.co/vOPcaZAg']
# [('15', 'CD'), ('million', 'CD'), ('americans', 'NNS'), ('suffer', 'VBP'), ('from', 'IN'), ('depression', 'NN'), ('.', '.')]
#
#
# ["Danone is excited at the prospect of joining forces with Sirma, as we believe we will benefit from the 2 companies' strong complementarities"]
# [('danone', 'NN'), ('is', 'VBZ'), ('excited', 'VBN'), ('at', 'IN'), ('the', 'DT'), ('prospect', 'NN'), ('of', 'IN'), ('joining', 'VBG'), ('force', 'NN'), ('with', 'IN'), ('sirma', 'NN'), (',', ','), ('a', 'DT'), ('we', 'PRP'), ('believe', 'VBP'), ('we', 'PRP'), ('will', 'MD'), ('benefit', 'VB'), ('from', 'IN'), ('the', 'DT'), ('2', 'CD'), ('company', 'NN'), ("'", 'POS'), ('strong', 'JJ'), ('complementarity', 'NN')]
#
#
# ['Despite stresses of today, survey finds women and men set health & wellness goals \x89ÛÒ but sex often influences success http://bit.ly/7S06hX']
# [('despite', 'IN'), ('stress', 'NN'), ('of', 'IN'), ('today', 'NN'), (',', ','), ('survey', 'NN'), ('find', 'VBP'), ('woman', 'NN'), ('and', 'CC'), ('men', 'NNS'), ('set', 'VBD'), ('health', 'NN'), ('&', 'CC'), ('wellness', 'NN'), ('goal', 'NN'), ('\x89ûò', 'NN'), ('but', 'CC'), ('sex', 'NN'), ('often', 'RB'), ('influence', 'JJ'), ('success', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ["@SpringboardEnt Oracle Award winner, Pfizer's Adele Gulfo, @gulfoa: At inflection points, the more challenging path will lead to greatness"]
# [('@', 'JJ'), ('springboardent', 'JJ'), ('oracle', 'NN'), ('award', 'NN'), ('winner', 'NN'), (',', ','), ('pfizer', 'NN'), ("'s", 'POS'), ('adele', 'JJ'), ('gulfo', 'NN'), (',', ','), ('@', 'JJ'), ('gulfoa', 'NN'), (':', ':'), ('at', 'IN'), ('inflection', 'NN'), ('point', 'NN'), (',', ','), ('the', 'DT'), ('more', 'RBR'), ('challenging', 'JJ'), ('path', 'NN'), ('will', 'MD'), ('lead', 'VB'), ('to', 'TO'), ('greatness', 'VB')]
#
#
# ['#HealthyBytes 8: Take a guess!', 'Does sleep deprivation make you fatter or slimmer?', 'Watch the video http://t.co/7qOBZz0tSa']
# [('#', '#'), ('healthybytes', 'VBZ'), ('8', 'CD'), (':', ':'), ('take', 'VB'), ('a', 'DT'), ('guess', 'NN'), ('!', '.')]
#
#
# ['For International Day of Happiness 2day, check out 10 keys to happier living, including ways to stay healthy: http://t.co/4mcmgDSptJ #BeWell']
# [('for', 'IN'), ('international', 'JJ'), ('day', 'NN'), ('of', 'IN'), ('happiness', 'NN'), ('2day', 'CD'), (',', ','), ('check', 'VB'), ('out', 'RP'), ('10', 'CD'), ('key', 'NN'), ('to', 'TO'), ('happier', 'VB'), ('living', 'NN'), (',', ','), ('including', 'VBG'), ('way', 'NN'), ('to', 'TO'), ('stay', 'VB'), ('healthy', 'JJ'), (':', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('bewell', 'NN')]
#
#
# ["We're very pleased to be the no.1 food company in the Dow Jones Sustainability Index this year: http://t.co/gBEXYQm9q2   #DJSI #Nestle"]
# [('we', 'PRP'), ("'re", 'VBP'), ('very', 'RB'), ('pleased', 'JJ'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('no.1', 'JJ'), ('food', 'NN'), ('company', 'NN'), ('in', 'IN'), ('the', 'DT'), ('dow', 'NN'), ('jones', 'NNS'), ('sustainability', 'NN'), ('index', 'NN'), ('this', 'DT'), ('year', 'NN'), (':', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('djsi', 'JJ'), ('#', '#'), ('nestle', 'JJ')]
#
#
# ['@CHEPhealthed Update: Australian tests reconfirm #Nestle NAN H.A.', '1 Gold infant formula is safe.', 'More here: http://t.co/OsLjuDg1']
# [('@', 'NN'), ('chephealthed', 'VBD'), ('update', 'JJ'), (':', ':'), ('australian', 'JJ'), ('test', 'NN'), ('reconfirm', 'NN'), ('#', '#'), ('nestle', 'JJ'), ('nan', 'JJ'), ('h.a', 'NN'), ('.', '.')]
#
#
# ['Pfizer is proud to be a founding sponsor of the Metastatic Breast Cancer Alliance @mbcalliance.', 'Learn more at http://t.co/zZfFRQ21ob #MBCA']
# [('pfizer', 'NN'), ('is', 'VBZ'), ('proud', 'JJ'), ('to', 'TO'), ('be', 'VB'), ('a', 'DT'), ('founding', 'JJ'), ('sponsor', 'NN'), ('of', 'IN'), ('the', 'DT'), ('metastatic', 'JJ'), ('breast', 'NN'), ('cancer', 'NN'), ('alliance', 'NN'), ('@', 'NNP'), ('mbcalliance', 'NN'), ('.', '.')]
#
#
# ['@Dannon Company is committed to helping #Americans make better food choices and to eat #yogurt every day @OneYogurt #US']
# [('@', 'NN'), ('dannon', 'NN'), ('company', 'NN'), ('is', 'VBZ'), ('committed', 'VBN'), ('to', 'TO'), ('helping', 'VBG'), ('#', '#'), ('americans', 'NNS'), ('make', 'VBP'), ('better', 'JJR'), ('food', 'NN'), ('choice', 'NN'), ('and', 'CC'), ('to', 'TO'), ('eat', 'VB'), ('#', '#'), ('yogurt', 'NN'), ('every', 'DT'), ('day', 'NN'), ('@', 'NNP'), ('oneyogurt', 'NN'), ('#', '#'), ('us', 'PRP')]
#
#
# ['Wealth &amp  Investment Management wins Wealth Manager of the Year award #GlobalInvestorAwards http://t.co/6z8N3xZg3b']
# [('wealth', 'NN'), ('&', 'CC'), ('amp', 'VB'), ('investment', 'NN'), ('management', 'NN'), ('win', 'VBP'), ('wealth', 'NN'), ('manager', 'NN'), ('of', 'IN'), ('the', 'DT'), ('year', 'NN'), ('award', 'RB'), ('#', '#'), ('globalinvestorawards', 'NNS'), ('urlplaceholder', 'NN')]
#
#
# ['RT @WSJWealthReport Fair for Millionaires Flops - What if they held a millionaire fair and no one came?', 'That is pre... http://ow.ly/15XnN0']
# [('rt', 'NN'), ('@', 'NNP'), ('wsjwealthreport', 'NN'), ('fair', 'NN'), ('for', 'IN'), ('millionaires', 'NNS'), ('flops', 'SYM'), ('-', ':'), ('what', 'WP'), ('if', 'IN'), ('they', 'PRP'), ('held', 'VBD'), ('a', 'DT'), ('millionaire', 'NN'), ('fair', 'NN'), ('and', 'CC'), ('no', 'DT'), ('one', 'NN'), ('came', 'VBD'), ('?', '.')]
#
#
# ['Slow Growth Emboldens Fed to Stay the Course:  http://t.co/VIoVGVqAVR #Citigroup #BRK']
# [('slow', 'JJ'), ('growth', 'NN'), ('emboldens', 'VBZ'), ('fed', 'VBN'), ('to', 'TO'), ('stay', 'VB'), ('the', 'DT'), ('course', 'NN'), (':', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('citigroup', 'NN'), ('#', '#'), ('brk', 'NN')]
#
#
# ['Pfizer EVP Laurie Olson: Our coalition w/ @LupusOrg is example of collaboration at work #Lupus']
# [('pfizer', 'NN'), ('evp', 'CC'), ('laurie', 'JJ'), ('olson', 'NN'), (':', ':'), ('our', 'PRP$'), ('coalition', 'NN'), ('w/', 'NN'), ('@', 'NNP'), ('lupusorg', 'NN'), ('is', 'VBZ'), ('example', 'NN'), ('of', 'IN'), ('collaboration', 'NN'), ('at', 'IN'), ('work', 'NN'), ('#', '#'), ('lupus', 'NN')]
#
#
# ['Exclusive: Fed pushes banks to ignore rivals when setting bonuses: The Federal Reserve is push... http://t.co/JWG4d9EhN4 #Citigroup #BRK']
# [('exclusive', 'JJ'), (':', ':'), ('fed', 'NNS'), ('push', 'VBP'), ('bank', 'NN'), ('to', 'TO'), ('ignore', 'VB'), ('rival', 'JJ'), ('when', 'WRB'), ('setting', 'VBG'), ('bonus', 'NN'), (':', ':'), ('the', 'DT'), ('federal', 'JJ'), ('reserve', 'NN'), ('is', 'VBZ'), ('push', 'JJ'), ('...', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('citigroup', 'NN'), ('#', '#'), ('brk', 'NN')]
#
#
# ["RT WSJ Wealth Report Is the IRS's 'Wealth Squad' Working?", '- The IRS has garnered a lot of headlines with its crackdo... http://ow.ly/1cHw8l']
# [('rt', 'NN'), ('wsj', 'WRB'), ('wealth', 'NN'), ('report', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('irs', 'NN'), ("'s", 'POS'), ("'wealth", 'NN'), ('squad', 'NN'), ("'", "''"), ('working', 'VBG'), ('?', '.')]
#
#
# ['@Pfizer has launched http://t.co/DQGWn2jaIc!', 'Learn how parents can help teens manage their own health http://t.co/70VgfMfyzF']
# [('@', 'JJ'), ('pfizer', 'NN'), ('ha', 'NN'), ('launched', 'VBN'), ('urlplaceholder', 'NN')]
#
#
# ['Emma Turner, Head of Client Philanthropy provides a short insight into giving.', 'Catch her latest blog here.', '#charity http://t.co/5YaLwoeoSm']
# [('emma', 'NN'), ('turner', 'NN'), (',', ','), ('head', 'NN'), ('of', 'IN'), ('client', 'NN'), ('philanthropy', 'NN'), ('provides', 'VBZ'), ('a', 'DT'), ('short', 'JJ'), ('insight', 'NN'), ('into', 'IN'), ('giving', 'VBG'), ('.', '.')]
#
#
# ['#HealthyBytes 4: Stuck in traffic again?', 'These simple exercises will help you to pass the time and stay fit!', 'http://t.co/PDRSn3u1VI']
# [('#', '#'), ('healthybytes', 'VBZ'), ('4', 'CD'), (':', ':'), ('stuck', 'VBN'), ('in', 'IN'), ('traffic', 'NN'), ('again', 'RB'), ('?', '.')]
#
#
# ['#Prostokvashino, the leading national food brand excluding beverages in Russia, is experiencing double-digit growth http://t.co/9UuWSn8Map']
# [('#', '#'), ('prostokvashino', 'NN'), (',', ','), ('the', 'DT'), ('leading', 'VBG'), ('national', 'JJ'), ('food', 'NN'), ('brand', 'NN'), ('excluding', 'VBG'), ('beverage', 'NN'), ('in', 'IN'), ('russia', 'NN'), (',', ','), ('is', 'VBZ'), ('experiencing', 'VBG'), ('double-digit', 'JJ'), ('growth', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Have you joined our #merckformothers community on FB?', 'http://t.co/p2OeJCF1EE']
# [('have', 'VB'), ('you', 'PRP'), ('joined', 'VBN'), ('our', 'PRP$'), ('#', '#'), ('merckformothers', 'NNS'), ('community', 'NN'), ('on', 'IN'), ('fb', 'NN'), ('?', '.')]
#
#
# ['Entrepreneurial activity on the up in last six months of 2012 http://t.co/Sxfx9xDl94 Barclays Entrepreneurs Index in City AM']
# [('entrepreneurial', 'JJ'), ('activity', 'NN'), ('on', 'IN'), ('the', 'DT'), ('up', 'RP'), ('in', 'IN'), ('last', 'JJ'), ('six', 'CD'), ('month', 'NN'), ('of', 'IN'), ('2012', 'CD'), ('urlplaceholder', 'NN'), ('barclays', 'NNS'), ('entrepreneurs', 'VBP'), ('index', 'NN'), ('in', 'IN'), ('city', 'NN'), ('am', 'VBP')]
#
#
# ['Barclays Wealth tops Customer Service Awards.', 'http://t.co/muPHJ7Cg']
# [('barclays', 'NNS'), ('wealth', 'VBP'), ('top', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('awards', 'NNS'), ('.', '.')]
#
#
# ['A fiscal warning from two former budget chiefs: Two former budget chiefs who worked for presid... http://t.co/nMraWaP2hP #Citigroup #BRK']
# [('a', 'DT'), ('fiscal', 'JJ'), ('warning', 'NN'), ('from', 'IN'), ('two', 'CD'), ('former', 'JJ'), ('budget', 'NN'), ('chief', 'NN'), (':', ':'), ('two', 'CD'), ('former', 'JJ'), ('budget', 'NN'), ('chief', 'NN'), ('who', 'WP'), ('worked', 'VBD'), ('for', 'IN'), ('presid', 'NN'), ('...', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('citigroup', 'NN'), ('#', '#'), ('brk', 'NN')]
#
#
# ['#Citi is proud to support the work of @GrahamWindham  and their diverse programs helping children in need in #NYC http://t.co/NCGBTxSqmQ']
# [('#', '#'), ('citi', 'NN'), ('is', 'VBZ'), ('proud', 'JJ'), ('to', 'TO'), ('support', 'VB'), ('the', 'DT'), ('work', 'NN'), ('of', 'IN'), ('@', 'NNP'), ('grahamwindham', 'NN'), ('and', 'CC'), ('their', 'PRP$'), ('diverse', 'JJ'), ('program', 'NN'), ('helping', 'VBG'), ('child', 'NN'), ('in', 'IN'), ('need', 'NN'), ('in', 'IN'), ('#', '#'), ('nyc', 'JJ'), ('urlplaceholder', 'NN')]
#
#
# ['RT @WSJWealthReport Does the Gates Foundation Need a $500 Million Complex?', 'http://ow.ly/1625QH']
# [('rt', 'NN'), ('@', 'FW'), ('wsjwealthreport', 'NN'), ('does', 'VBZ'), ('the', 'DT'), ('gates', 'NNS'), ('foundation', 'VBP'), ('need', 'VBP'), ('a', 'DT'), ('$', '$'), ('500', 'CD'), ('million', 'CD'), ('complex', 'NN'), ('?', '.')]
#
#
# ['New RA treatment discovered and developed in PFE\x89Ûªs Connecticut labs']
# [('new', 'JJ'), ('ra', 'NN'), ('treatment', 'NN'), ('discovered', 'VBD'), ('and', 'CC'), ('developed', 'VBD'), ('in', 'IN'), ('pfe\x89ûªs', 'NN'), ('connecticut', 'NN'), ('lab', 'NN')]
#
#
# ["Citigroup and Blackstone's Capital Requirement Workaround: [at CNBC] - A year ago, Citi bought... http://t.co/b3A431eGxw #Citigroup #BRK"]
# [('citigroup', 'NN'), ('and', 'CC'), ('blackstone', 'NN'), ("'s", 'POS'), ('capital', 'NN'), ('requirement', 'NN'), ('workaround', 'NN'), (':', ':'), ('[', 'NN'), ('at', 'IN'), ('cnbc', 'NN'), (']', 'NNP'), ('-', ':'), ('a', 'DT'), ('year', 'NN'), ('ago', 'RB'), (',', ','), ('citi', 'NN'), ('bought', 'VBD'), ('...', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('citigroup', 'NN'), ('#', '#'), ('brk', 'NN')]
#
#
# ['@shesthefirst A great collaborative effort!']
# [('@', 'NN'), ('shesthefirst', 'VBZ'), ('a', 'DT'), ('great', 'JJ'), ('collaborative', 'JJ'), ('effort', 'NN'), ('!', '.')]
#
#
# ['RT @WSJEconomy: Euro Zone Posts Trade Deficit http://bit.ly/sjlI2']
# [('rt', 'NN'), ('@', 'JJ'), ('wsjeconomy', 'NN'), (':', ':'), ('euro', 'NN'), ('zone', 'NN'), ('posts', 'NNS'), ('trade', 'NN'), ('deficit', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Barclays sponsors exhibition of landscape photography in association with @PositiveViewF http://t.co/HkSEwCHsN7']
# [('barclays', 'NNS'), ('sponsor', 'VBP'), ('exhibition', 'NN'), ('of', 'IN'), ('landscape', 'NN'), ('photography', 'NN'), ('in', 'IN'), ('association', 'NN'), ('with', 'IN'), ('@', 'NNP'), ('positiveviewf', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['@whoozqueen #Nestle NAN H.A.', '1 Gold Infant Formula is safe.', 'Please check this page for more info:  http://t.co/OsLjuDg1']
# [('@', 'RB'), ('whoozqueen', 'JJ'), ('#', '#'), ('nestle', 'JJ'), ('nan', 'JJ'), ('h.a', 'NN'), ('.', '.')]
#
#
# ['Pfizer Global Health Fellow Yolande Morris addressing health issues for underserved populations from Rwanda http://t.co/Kh8rsc91']
# [('pfizer', 'NN'), ('global', 'JJ'), ('health', 'NN'), ('fellow', 'JJ'), ('yolande', 'NN'), ('morris', 'NN'), ('addressing', 'VBG'), ('health', 'NN'), ('issue', 'NN'), ('for', 'IN'), ('underserved', 'JJ'), ('population', 'NN'), ('from', 'IN'), ('rwanda', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ["'Philanthropology: The Evolution of Giving' - Barclays Wealth identifies the characteristics of wealthy philanthropists.", 'http://su.pr/9L1oeg']
# [("'philanthropology", 'NN'), (':', ':'), ('the', 'DT'), ('evolution', 'NN'), ('of', 'IN'), ('giving', 'VBG'), ("'", "''"), ('-', ':'), ('barclays', 'NNS'), ('wealth', 'VBP'), ('identifies', 'VBZ'), ('the', 'DT'), ('characteristic', 'NN'), ('of', 'IN'), ('wealthy', 'JJ'), ('philanthropist', 'NN'), ('.', '.')]
#
#
# ['@Dannon awarded  Food Packagers of the year  : http://t.co/pqgSjFym #innovation']
# [('@', 'NN'), ('dannon', 'NN'), ('awarded', 'VBD'), ('food', 'NN'), ('packagers', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('year', 'NN'), (':', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('innovation', 'NN')]
#
#
# ['@DhirajShekar Great Work!', 'Thanks for giving back!']
# [('@', 'JJ'), ('dhirajshekar', 'NN'), ('great', 'JJ'), ('work', 'NN'), ('!', '.')]
#
#
# ['Merck Heroes: A new feature spotlighting our employee volunteers!', 'Check it out: http://t.co/UCRgqN9w2R']
# [('merck', 'NN'), ('heroes', 'NNS'), (':', ':'), ('a', 'DT'), ('new', 'JJ'), ('feature', 'NN'), ('spotlighting', 'VBG'), ('our', 'PRP$'), ('employee', 'NN'), ('volunteer', 'NN'), ('!', '.')]
#
#
# ['"For companies, investing in women can mean better health, education - and business" via @globalpost: http://t.co/bAHU1xMn2y']
# [('``', '``'), ('for', 'IN'), ('company', 'NN'), (',', ','), ('investing', 'VBG'), ('in', 'IN'), ('woman', 'NN'), ('can', 'MD'), ('mean', 'VB'), ('better', 'JJR'), ('health', 'NN'), (',', ','), ('education', 'NN'), ('-', ':'), ('and', 'CC'), ('business', 'NN'), ("''", "''"), ('via', 'IN'), ('@', 'JJ'), ('globalpost', 'NN'), (':', ':'), ('urlplaceholder', 'NN')]
#
#
# ['#Nestle Health Science and Chi-Med have agreed to form a new partnership named #Nutrition Science Partners Limited: http://t.co/d6yIMtUC']
# [('#', '#'), ('nestle', 'JJ'), ('health', 'NN'), ('science', 'NN'), ('and', 'CC'), ('chi-med', 'JJ'), ('have', 'VBP'), ('agreed', 'VBN'), ('to', 'TO'), ('form', 'VB'), ('a', 'DT'), ('new', 'JJ'), ('partnership', 'NN'), ('named', 'VBN'), ('#', '#'), ('nutrition', 'NN'), ('science', 'NN'), ('partners', 'NNS'), ('limited', 'VBD'), (':', ':'), ('urlplaceholder', 'NN')]
#
#
# ['RT @DownTo_Earth_ : In Ukraine, giving voice to the beneficiaries through an ethnographic study http://t.co/zmCQteGA #sustainability']
# [('rt', 'NN'), ('@', 'NN'), ('downto_earth_', 'NN'), (':', ':'), ('in', 'IN'), ('ukraine', 'NN'), (',', ','), ('giving', 'VBG'), ('voice', 'NN'), ('to', 'TO'), ('the', 'DT'), ('beneficiary', 'NN'), ('through', 'IN'), ('an', 'DT'), ('ethnographic', 'JJ'), ('study', 'NN'), ('urlplaceholder', 'JJ'), ('#', '#'), ('sustainability', 'NN')]
#
#
# ['We continue to develop our operations in #Chile with the opening of a new dairy factory http://t.co/MP5DIrIo #nestle']
# [('we', 'PRP'), ('continue', 'VBP'), ('to', 'TO'), ('develop', 'VB'), ('our', 'PRP$'), ('operation', 'NN'), ('in', 'IN'), ('#', '#'), ('chile', 'NN'), ('with', 'IN'), ('the', 'DT'), ('opening', 'NN'), ('of', 'IN'), ('a', 'DT'), ('new', 'JJ'), ('dairy', 'NN'), ('factory', 'NN'), ('urlplaceholder', 'JJ'), ('#', '#'), ('nestle', 'JJ')]
#
#
# [' We still have more to do, but the foundation for future success has been built.', "#Citi's CEO Corbat at Annual Mtg.", 'http://t.co/Sv2Ng2mlKL']
# [('we', 'PRP'), ('still', 'RB'), ('have', 'VBP'), ('more', 'JJR'), ('to', 'TO'), ('do', 'VB'), (',', ','), ('but', 'CC'), ('the', 'DT'), ('foundation', 'NN'), ('for', 'IN'), ('future', 'JJ'), ('success', 'NN'), ('ha', 'NN'), ('been', 'VBN'), ('built', 'VBN'), ('.', '.')]
#
#
# ['MBIA and BofA Reach Accord On Dispute and 2 More Heavily Traded Stocks To Follow:  http://t.co/WaZw0Qbvpn #Citigroup #BRK']
# [('mbia', 'NN'), ('and', 'CC'), ('bofa', 'VB'), ('reach', 'NN'), ('accord', 'NN'), ('on', 'IN'), ('dispute', 'NN'), ('and', 'CC'), ('2', 'CD'), ('more', 'JJR'), ('heavily', 'RB'), ('traded', 'JJ'), ('stocks', 'NNS'), ('to', 'TO'), ('follow', 'VB'), (':', ':'), ('urlplaceholder', 'NN'), ('#', '#'), ('citigroup', 'NN'), ('#', '#'), ('brk', 'NN')]
#
#
# ['New report highlights 100bn impact of major social issues and emphasises importance of early intervention http://t.co/AkskkGNh']
# [('new', 'JJ'), ('report', 'NN'), ('highlight', 'VBD'), ('100bn', 'CD'), ('impact', 'NN'), ('of', 'IN'), ('major', 'JJ'), ('social', 'JJ'), ('issue', 'NN'), ('and', 'CC'), ('emphasis', 'NN'), ('importance', 'NN'), ('of', 'IN'), ('early', 'JJ'), ('intervention', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['NestlÌ© earmarked for top environment award http://bit.ly/gsXwPM']
# [('nestlì©', 'NN'), ('earmarked', 'VBD'), ('for', 'IN'), ('top', 'JJ'), ('environment', 'NN'), ('award', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ["Kids are more likely to try vegetables that they've helped grow: http://t.co/FTOffZqXig #HealthyTips http://t.co/G9QKrxHjqM"]
# [('kids', 'NNS'), ('are', 'VBP'), ('more', 'RBR'), ('likely', 'JJ'), ('to', 'TO'), ('try', 'VB'), ('vegetable', 'JJ'), ('that', 'IN'), ('they', 'PRP'), ("'ve", 'VBP'), ('helped', 'VBN'), ('grow', 'VB'), (':', ':'), ('urlplaceholder', 'NN'), ('#', '#'), ('healthytips', 'NNS'), ('urlplaceholder', 'VBP')]
#
#
# ['Peter Brabeck-Letmathe speaks to Reuters about how Creating Shared Value contrasts with philanthropy http://reut.rs/gRYFjr #CSV']
# [('peter', 'NN'), ('brabeck-letmathe', 'JJ'), ('speaks', 'NNS'), ('to', 'TO'), ('reuters', 'NNS'), ('about', 'IN'), ('how', 'WRB'), ('creating', 'VBG'), ('shared', 'VBN'), ('value', 'NN'), ('contrast', 'NN'), ('with', 'IN'), ('philanthropy', 'JJ'), ('urlplaceholder', 'JJ'), ('#', '#'), ('csv', 'NN')]
#
#
# ['...Visit us @NAPFnews 5-7 March for more workforce insights.', '#NAPF #pension http://t.co/eR9REnMww6 http://t.co/HCbfiJBJkB']
# [('...', ':'), ('visit', 'NN'), ('u', 'JJ'), ('@', 'JJ'), ('napfnews', 'NNS'), ('5-7', 'JJ'), ('march', 'NN'), ('for', 'IN'), ('more', 'JJR'), ('workforce', 'NN'), ('insight', 'NN'), ('.', '.')]
#
#
# ['Sumitomo Mitsui Banking Corp., Barclays Wealth & Nikko Cordial Securities Inc. announce private banking joint venture.', 'http://ow.ly/25FOZ']
# [('sumitomo', 'NN'), ('mitsui', 'NNS'), ('banking', 'VBG'), ('corp.', 'NN'), (',', ','), ('barclays', 'VBZ'), ('wealth', 'NN'), ('&', 'CC'), ('nikko', 'JJ'), ('cordial', 'JJ'), ('securities', 'NNS'), ('inc.', 'VBP'), ('announce', 'RB'), ('private', 'JJ'), ('banking', 'NN'), ('joint', 'JJ'), ('venture', 'NN'), ('.', '.')]
#
#
# ['Malaysia: @Citibank brings home 5 customer service awards Ì¢\x89âÂ\x89ÛÏ CitiPhone Banking wins in 3 categories!', 'http://t.co/lKPBLWSjaq']
# [('malaysia', 'NN'), (':', ':'), ('@', 'JJ'), ('citibank', 'NN'), ('brings', 'VBZ'), ('home', 'NN'), ('5', 'CD'), ('customer', 'NN'), ('service', 'NN'), ('award', 'RB'), ('ì¢\x89ââ\x89ûï', 'NNP'), ('citiphone', 'NN'), ('banking', 'NN'), ('win', 'NN'), ('in', 'IN'), ('3', 'CD'), ('category', 'NN'), ('!', '.')]
#
#
# ['A Vassiliou:  #Nestle is showing that stakeholders can work together to bring about change  #employment4youth']
# [('a', 'DT'), ('vassiliou', 'NN'), (':', ':'), ('#', '#'), ('nestle', 'NN'), ('is', 'VBZ'), ('showing', 'VBG'), ('that', 'IN'), ('stakeholder', 'NN'), ('can', 'MD'), ('work', 'VB'), ('together', 'RB'), ('to', 'TO'), ('bring', 'VB'), ('about', 'RP'), ('change', 'NN'), ('#', '#'), ('employment4youth', 'NN')]
#
#
# ['Taiwan: Second Citi Future Leaders Development Program Awards Ceremony: [at noodls] - For Imme... http://t.co/e0Ukj0zK2v #Citigroup #BRK']
# [('taiwan', 'NN'), (':', ':'), ('second', 'JJ'), ('citi', 'JJ'), ('future', 'NN'), ('leaders', 'NNS'), ('development', 'NN'), ('program', 'NN'), ('awards', 'NNS'), ('ceremony', 'NN'), (':', ':'), ('[', 'NN'), ('at', 'IN'), ('noodls', 'JJ'), (']', 'NNP'), ('-', ':'), ('for', 'IN'), ('imme', 'NN'), ('...', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('citigroup', 'NN'), ('#', '#'), ('brk', 'NN')]
#
#
# [' Disasters are always personal and human stories  Patrick Chappatte #TEDxRC2']
# [('disasters', 'NNS'), ('are', 'VBP'), ('always', 'RB'), ('personal', 'JJ'), ('and', 'CC'), ('human', 'JJ'), ('story', 'NN'), ('patrick', 'NN'), ('chappatte', 'NN'), ('#', '#'), ('tedxrc2', 'NN')]
#
#
# ['Maria Nowak :  In the field of social and solidarity-based economy, what matters for NGOs is escaping their isolation  http://t.co/1OgMfqdL']
# [('maria', 'NNS'), ('nowak', 'NNS'), (':', ':'), ('in', 'IN'), ('the', 'DT'), ('field', 'NN'), ('of', 'IN'), ('social', 'JJ'), ('and', 'CC'), ('solidarity-based', 'JJ'), ('economy', 'NN'), (',', ','), ('what', 'WP'), ('matter', 'NN'), ('for', 'IN'), ('ngos', 'NN'), ('is', 'VBZ'), ('escaping', 'VBG'), ('their', 'PRP$'), ('isolation', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Pfizer celebrated National Health Center Week at Southwest Community Health Center in CT.', 'Learn more-http://www.healthcenterweek.org/']
# [('pfizer', 'NN'), ('celebrated', 'VBN'), ('national', 'JJ'), ('health', 'NN'), ('center', 'NN'), ('week', 'NN'), ('at', 'IN'), ('southwest', 'JJS'), ('community', 'NN'), ('health', 'NN'), ('center', 'NN'), ('in', 'IN'), ('ct', 'NN'), ('.', '.')]
#
#
# ['@DoulaKim Our #Nestle NAN H.A.', '1 Gold infant formula is safe.', 'You can read more here: http://t.co/OsLjuDg1']
# [('@', 'NN'), ('doulakim', 'VBZ'), ('our', 'PRP$'), ('#', '#'), ('nestle', 'JJ'), ('nan', 'JJ'), ('h.a', 'NN'), ('.', '.')]
#
#
# ['#nestle CEO in the kitchen \x89ÛÒ as Malaysians make healthy pledge http://t.co/GfWn0qXb3o http://t.co/uRg6lkLOOS']
# [('#', '#'), ('nestle', 'JJ'), ('ceo', 'NN'), ('in', 'IN'), ('the', 'DT'), ('kitchen', 'NN'), ('\x89ûò', 'VBZ'), ('a', 'DT'), ('malaysians', 'NNS'), ('make', 'VBP'), ('healthy', 'JJ'), ('pledge', 'NN'), ('urlplaceholder', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['\x89Û÷Get on your bike\x89Ûª - the benefits of cycling from health &amp  freedom through to environment &amp  cost.Watch the video here http://t.co/MhoQFPOw']
# [('\x89û÷get', 'VB'), ('on', 'IN'), ('your', 'PRP$'), ('bike\x89ûª', 'NN'), ('-', ':'), ('the', 'DT'), ('benefit', 'NN'), ('of', 'IN'), ('cycling', 'VBG'), ('from', 'IN'), ('health', 'NN'), ('&', 'CC'), ('amp', 'NN'), ('freedom', 'NN'), ('through', 'IN'), ('to', 'TO'), ('environment', 'NN'), ('&', 'CC'), ('amp', 'NN'), ('cost.watch', 'VBP'), ('the', 'DT'), ('video', 'NN'), ('here', 'RB'), ('urlplaceholder', 'NN')]
#
#
# ['#Prostokvashino, the leading national food brand excluding beverages in Russia, is experiencing double-digit growth http://t.co/9UuWSn8Map']
# [('#', '#'), ('prostokvashino', 'NN'), (',', ','), ('the', 'DT'), ('leading', 'VBG'), ('national', 'JJ'), ('food', 'NN'), ('brand', 'NN'), ('excluding', 'VBG'), ('beverage', 'NN'), ('in', 'IN'), ('russia', 'NN'), (',', ','), ('is', 'VBZ'), ('experiencing', 'VBG'), ('double-digit', 'JJ'), ('growth', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Governor Tom Corbett visited our PA manufacturing facility on Tuesday, July 16.', 'Check out a photo from his visit!', 'http://t.co/cFrQOk6s6t']
# [('governor', 'NN'), ('tom', 'NN'), ('corbett', 'NN'), ('visited', 'VBD'), ('our', 'PRP$'), ('pa', 'NN'), ('manufacturing', 'NN'), ('facility', 'NN'), ('on', 'IN'), ('tuesday', 'NN'), (',', ','), ('july', 'RB'), ('16', 'CD'), ('.', '.')]
#
#
# ['#ICYMI: Nestle UK wins innovation award for school leavers scheme.', 'http://t.co/9Sk4XABS80 http://t.co/bCFmY9ziP7']
# [('#', '#'), ('icymi', 'NN'), (':', ':'), ('nestle', 'JJ'), ('uk', 'JJ'), ('win', 'NN'), ('innovation', 'NN'), ('award', 'NN'), ('for', 'IN'), ('school', 'NN'), ('leaver', 'NN'), ('scheme', 'NN'), ('.', '.')]
#
#
# ['@GovernorCorbett So proud to show you where we make and ship products throughout the world.', 'Thank you for the great visit!']
# ...
#
#
# ["@FoodMuse looking into it, but it's the weekend on the west coast soon .. hope for an answer next week"]
# [('@', 'NN'), ('foodmuse', 'NN'), ('looking', 'VBG'), ('into', 'IN'), ('it', 'PRP'), (',', ','), ('but', 'CC'), ('it', 'PRP'), ("'s", 'VBZ'), ('the', 'DT'), ('weekend', 'NN'), ('on', 'IN'), ('the', 'DT'), ('west', 'NN'), ('coast', 'NN'), ('soon', 'RB'), ('..', 'NNP'), ('hope', 'NN'), ('for', 'IN'), ('an', 'DT'), ('answer', 'NN'), ('next', 'JJ'), ('week', 'NN')]
#
#
# ['NestlÌ© Health Science CEO Luis Cantarell: \x89ÛÏOur stake in Accera is a strategic step forward in building up our brain health portfolio.']
# [('nestlì©', 'JJ'), ('health', 'NN'), ('science', 'NN'), ('ceo', 'NN'), ('luis', 'NN'), ('cantarell', 'NN'), (':', ':'), ('\x89ûïour', 'JJ'), ('stake', 'NN'), ('in', 'IN'), ('accera', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('strategic', 'JJ'), ('step', 'NN'), ('forward', 'RB'), ('in', 'IN'), ('building', 'VBG'), ('up', 'RP'), ('our', 'PRP$'), ('brain', 'NN'), ('health', 'NN'), ('portfolio', 'NN'), ('.', '.')]
#
#
# ['@kpolyc Read the most important action we will take in 2012 to tackle the #child #labour issue http://t.co/7r5jiNOW']
# [('@', 'JJ'), ('kpolyc', 'NN'), ('read', 'VBD'), ('the', 'DT'), ('most', 'RBS'), ('important', 'JJ'), ('action', 'NN'), ('we', 'PRP'), ('will', 'MD'), ('take', 'VB'), ('in', 'IN'), ('2012', 'CD'), ('to', 'TO'), ('tackle', 'VB'), ('the', 'DT'), ('#', '#'), ('child', 'JJ'), ('#', '#'), ('labour', 'JJ'), ('issue', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['#Superbugs are becoming more resistant to #Antibiotics - researchers are working on a solution #lysogenization http://t.co/8GXADzbI']
# [('#', '#'), ('superbugs', 'NNS'), ('are', 'VBP'), ('becoming', 'VBG'), ('more', 'RBR'), ('resistant', 'JJ'), ('to', 'TO'), ('#', '#'), ('antibiotics', 'NNS'), ('-', ':'), ('researcher', 'NN'), ('are', 'VBP'), ('working', 'VBG'), ('on', 'IN'), ('a', 'DT'), ('solution', 'NN'), ('#', '#'), ('lysogenization', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Barclays Wealth sponsors 2011 Commonwealth Youth Games.', 'http://su.pr/2yeR8b']
# [('barclays', 'NNS'), ('wealth', 'NN'), ('sponsor', 'NN'), ('2011', 'CD'), ('commonwealth', 'NN'), ('youth', 'NN'), ('games', 'NNS'), ('.', '.')]
#
#
# ['Can #soapoperas teach business skills?', 'See how Aprenda does this: http://t.co/kXtrvdKH8L #FTCitiAwards #progressmakers']
# [('can', 'MD'), ('#', '#'), ('soapoperas', 'VB'), ('teach', 'NN'), ('business', 'NN'), ('skill', 'NN'), ('?', '.')]
#
#
# ['To celebrate Global Community Day over 400 #CitiVolunteers in #Spain are collaborating w food banks, animal shelters, &amp; childrenÌ¢\x89âÂ\x89ã¢s hospitals']
# [('to', 'TO'), ('celebrate', 'VB'), ('global', 'JJ'), ('community', 'NN'), ('day', 'NN'), ('over', 'IN'), ('400', 'CD'), ('#', '#'), ('citivolunteers', 'NNS'), ('in', 'IN'), ('#', '#'), ('spain', 'NN'), ('are', 'VBP'), ('collaborating', 'VBG'), ('w', 'NNS'), ('food', 'NN'), ('bank', 'NN'), (',', ','), ('animal', 'JJ'), ('shelter', 'NN'), (',', ','), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('childrenì¢\x89ââ\x89ã¢s', 'JJ'), ('hospital', 'NN')]
#
#
# ['Danone Institute has been rewarded by El Centro CatalÌÄåÁn de NutriciÌÄå_n for its Food initiatives!', 'http://t.co/xRE9vLtBmr']
# [('danone', 'NN'), ('institute', 'NN'), ('ha', 'NN'), ('been', 'VBN'), ('rewarded', 'VBN'), ('by', 'IN'), ('el', 'JJ'), ('centro', 'NN'), ('catalìäåán', 'NN'), ('de', 'IN'), ('nutriciìäå_n', 'FW'), ('for', 'IN'), ('it', 'PRP'), ('food', 'NN'), ('initiative', 'NN'), ('!', '.')]
#
#
# ['AAHRPP Pres.', '&amp  CEO Marjorie A. Speers says Pfizer\x89Ûªs AAHRPP accreditation raises bar, sets an example for other sponsors to follow']
# [('aahrpp', 'NN'), ('pres', 'NNS'), ('.', '.')]
#
#
# ['Great photo!', 'RT @DaphneArs #CitiVolunteers #Venezuela ?', 'http://t.co/Als4uwgqBS']
# [('great', 'JJ'), ('photo', 'NN'), ('!', '.')]
#
#
# ['@HealthBridgeHIO Awesome!', 'Thanks for sharing!']
# [('@', 'JJ'), ('healthbridgehio', 'NN'), ('awesome', 'NN'), ('!', '.')]
#
#
# ['#MerckforMothers launches its U.S. program with leading maternal health organizations!', 'Learn more: http://t.co/Blw1ptBTnq']
# [('#', '#'), ('merckformothers', 'NNS'), ('launch', 'VBP'), ('it', 'PRP'), ('u.s.', 'JJ'), ('program', 'NN'), ('with', 'IN'), ('leading', 'VBG'), ('maternal', 'JJ'), ('health', 'NN'), ('organization', 'NN'), ('!', '.')]
#
#
# ['Tami Evans as a Pfizer Global Health Fellow: http://on.pfizer.com/f1WKTc']
# [('tami', 'NN'), ('evans', 'VBZ'), ('a', 'DT'), ('a', 'DT'), ('pfizer', 'NN'), ('global', 'JJ'), ('health', 'NN'), ('fellow', 'NN'), (':', ':'), ('urlplaceholder', 'NN')]
#
#
# ['@Pfizer sponsored symposium today discusses the present &amp  future outlook of #mRCC treatment options #ECC2013']
# [('@', 'JJ'), ('pfizer', 'NN'), ('sponsored', 'VBD'), ('symposium', 'NN'), ('today', 'NN'), ('discus', 'VB'), ('the', 'DT'), ('present', 'JJ'), ('&', 'CC'), ('amp', 'JJ'), ('future', 'JJ'), ('outlook', 'NN'), ('of', 'IN'), ('#', '#'), ('mrcc', 'FW'), ('treatment', 'NN'), ('option', 'NN'), ('#', '#'), ('ecc2013', 'NN')]
#
#
# ['Barclays announces result of Rights Issue http://t.co/LbIqqh3wwG']
# [('barclays', 'NNS'), ('announces', 'NNS'), ('result', 'NN'), ('of', 'IN'), ('rights', 'NNS'), ('issue', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Bob Libbey: #LetsGetOld That is how you build a community #BDI1']
# [('bob', 'NN'), ('libbey', 'NN'), (':', ':'), ('#', '#'), ('letsgetold', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('how', 'WRB'), ('you', 'PRP'), ('build', 'VBP'), ('a', 'DT'), ('community', 'NN'), ('#', '#'), ('bdi1', 'NN')]
#
#
# ['Pfizer produces healthcare resources guide for residents of #Bronx #NYC http://t.co/lBMolQprkT']
# [('pfizer', 'NN'), ('produce', 'VBP'), ('healthcare', 'NN'), ('resource', 'NN'), ('guide', 'NN'), ('for', 'IN'), ('resident', 'NN'), ('of', 'IN'), ('#', '#'), ('bronx', 'JJ'), ('#', '#'), ('nyc', 'JJ'), ('urlplaceholder', 'NN')]
#
#
# ['Gardening may help reduce stress and is a great way to enjoy the outdoors if done safely.', 'Check out these tips: http://t.co/yegHQio7JM']
# [('gardening', 'NN'), ('may', 'MD'), ('help', 'VB'), ('reduce', 'VB'), ('stress', 'NN'), ('and', 'CC'), ('is', 'VBZ'), ('a', 'DT'), ('great', 'JJ'), ('way', 'NN'), ('to', 'TO'), ('enjoy', 'VB'), ('the', 'DT'), ('outdoors', 'NNS'), ('if', 'IN'), ('done', 'VBN'), ('safely', 'RB'), ('.', '.')]
#
#
# ['#FOOD FACT: #IRON is important for blood formation and oxygen transport in the blood.', 'http://t.co/S4qzye1cN4']
# [('#', '#'), ('food', 'NN'), ('fact', 'NN'), (':', ':'), ('#', '#'), ('iron', 'NN'), ('is', 'VBZ'), ('important', 'JJ'), ('for', 'IN'), ('blood', 'NN'), ('formation', 'NN'), ('and', 'CC'), ('oxygen', 'NN'), ('transport', 'NN'), ('in', 'IN'), ('the', 'DT'), ('blood', 'NN'), ('.', '.')]
#
#
# ['Barclays announces that Irene McDermott Brown has been appointed as Group Human Resources Director http://t.co/c3fNGY6NMT']
# [('barclays', 'NNS'), ('announces', 'NNS'), ('that', 'WDT'), ('irene', 'VBP'), ('mcdermott', 'RBS'), ('brown', 'JJ'), ('ha', 'NN'), ('been', 'VBN'), ('appointed', 'VBN'), ('a', 'DT'), ('group', 'NN'), ('human', 'JJ'), ('resources', 'NNS'), ('director', 'NN'), ('urlplaceholder', 'NN')]
#
#
# [" With the help of Fair Labor Association we've identified 11 areas of recommendations to tackle child labour issue.", 'http://t.co/76Ttq66p']
# [('with', 'IN'), ('the', 'DT'), ('help', 'NN'), ('of', 'IN'), ('fair', 'JJ'), ('labor', 'NN'), ('association', 'NN'), ('we', 'PRP'), ("'ve", 'VBP'), ('identified', 'VBN'), ('11', 'CD'), ('area', 'NN'), ('of', 'IN'), ('recommendation', 'NN'), ('to', 'TO'), ('tackle', 'VB'), ('child', 'VB'), ('labour', 'JJ'), ('issue', 'NN'), ('.', '.')]
#
#
# ['Volunteers help to make a difference to rescue animals.', 'http://t.co/NupD1MAJ']
# [('volunteers', 'NNS'), ('help', 'VBP'), ('to', 'TO'), ('make', 'VB'), ('a', 'DT'), ('difference', 'NN'), ('to', 'TO'), ('rescue', 'VB'), ('animal', 'NN'), ('.', '.')]
#
#
# ['.', '@EAL_Awards Keep up the good work, Ed!', '#employment4youth']
# [('.', '.')]
#
#
# ['Pfizer Global Security Director David Shore panelist in Pharma IQ 2nd Annual Anti-counterfeiting Conference http://on.pfizer.com/igHSIQ']
# [('pfizer', 'NN'), ('global', 'JJ'), ('security', 'NN'), ('director', 'NN'), ('david', 'NN'), ('shore', 'NN'), ('panelist', 'NN'), ('in', 'IN'), ('pharma', 'JJ'), ('iq', 'NN'), ('2nd', 'CD'), ('annual', 'JJ'), ('anti-counterfeiting', 'JJ'), ('conference', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['#Nestle CFO "We\'ve grown by staying in touch with our consumers - delivering products that are tastier, healthier and affordable."']
# [('#', '#'), ('nestle', 'JJ'), ('cfo', 'NN'), ('``', '``'), ('we', 'PRP'), ("'ve", 'VBP'), ('grown', 'VBN'), ('by', 'IN'), ('staying', 'VBG'), ('in', 'IN'), ('touch', 'NN'), ('with', 'IN'), ('our', 'PRP$'), ('consumer', 'NN'), ('-', ':'), ('delivering', 'VBG'), ('product', 'NN'), ('that', 'WDT'), ('are', 'VBP'), ('tastier', 'JJR'), (',', ','), ('healthier', 'JJR'), ('and', 'CC'), ('affordable', 'JJ'), ('.', '.'), ("''", "''")]
#
#
# ['#4 is @DoPayLtd - Providing corporates a safer and cheaper way to pay their unbanked employees.', '#BarclaysAccel http://t.co/1OBIuL1NG7']
# [('#', '#'), ('4', 'CD'), ('is', 'VBZ'), ('@', 'VBN'), ('dopayltd', 'JJ'), ('-', ':'), ('providing', 'VBG'), ('corporates', 'VBZ'), ('a', 'DT'), ('safer', 'NN'), ('and', 'CC'), ('cheaper', 'JJR'), ('way', 'NN'), ('to', 'TO'), ('pay', 'VB'), ('their', 'PRP$'), ('unbanked', 'JJ'), ('employee', 'NN'), ('.', '.')]
#
#
# ['Look like fun!', 'RT @Lars2809 #Citi France global community day.', "It's harder than it actually looks #CitiVolunteers http://t.co/5WaIhwQ6SI"]
# [('look', 'NN'), ('like', 'IN'), ('fun', 'NN'), ('!', '.')]
#
#
# ['Z Bhutta: Problems with food&amp;land systems include land acquistion, commodity speculation affecting food prices&amp;lack of discussion #NINS2013']
# [('z', 'NN'), ('bhutta', 'NN'), (':', ':'), ('problems', 'NNS'), ('with', 'IN'), ('food', 'NN'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('land', 'NN'), ('system', 'NN'), ('include', 'VBP'), ('land', 'NN'), ('acquistion', 'NN'), (',', ','), ('commodity', 'NN'), ('speculation', 'NN'), ('affecting', 'VBG'), ('food', 'NN'), ('price', 'NN'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('lack', 'NN'), ('of', 'IN'), ('discussion', 'NN'), ('#', '#'), ('nins2013', 'NN')]
#
#
# ['Pfizer to acquire Ferrosan\x89Ûªs Consumer Healthcare Business http://on.pfizer.com/eG1wO3']
# [('pfizer', 'NN'), ('to', 'TO'), ('acquire', 'VB'), ('ferrosan\x89ûªs', 'JJ'), ('consumer', 'NN'), ('healthcare', 'NN'), ('business', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['Reverse Split Curse Continues For This ETF: Sometimes reverse splits work.', 'Sometimes the ploy ... http://t.co/k9dfmYEjqI #Citigroup #BRK']
# [('reverse', 'NN'), ('split', 'NN'), ('curse', 'NN'), ('continues', 'VBZ'), ('for', 'IN'), ('this', 'DT'), ('etf', 'NN'), (':', ':'), ('sometimes', 'RB'), ('reverse', 'VB'), ('split', 'NN'), ('work', 'NN'), ('.', '.')]
#
#
# ['\x89ÛÏCorporate responsibility underscores our steadfast commitment to help the world #BeWell.\x89Û\x9d \x89ÛÒ Ken C. Frazier, CEO http://t.co/BGajFdS3V6']
# [('\x89ûïcorporate', 'JJ'), ('responsibility', 'NN'), ('underscore', 'IN'), ('our', 'PRP$'), ('steadfast', 'NN'), ('commitment', 'NN'), ('to', 'TO'), ('help', 'VB'), ('the', 'DT'), ('world', 'NN'), ('#', '#'), ('bewell.\x89û\x9d', 'NN'), ('\x89ûò', 'NNP'), ('ken', 'NNP'), ('c.', 'NN'), ('frazier', 'NN'), (',', ','), ('ceo', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['For the latest Investor Relations news right in your e-mail inbox, sign up for our Citi News Alerts: http://t.co/Dq1SrKQLNn']
# [('for', 'IN'), ('the', 'DT'), ('latest', 'JJS'), ('investor', 'NN'), ('relations', 'NNS'), ('news', 'NN'), ('right', 'RB'), ('in', 'IN'), ('your', 'PRP$'), ('e-mail', 'JJ'), ('inbox', 'NN'), (',', ','), ('sign', 'VB'), ('up', 'RP'), ('for', 'IN'), ('our', 'PRP$'), ('citi', 'JJ'), ('news', 'NN'), ('alerts', 'NNS'), (':', ':'), ('urlplaceholder', 'NN')]
#
#
# ['@Wmur9 We have voluntarily recalled limited amounts of Nesquik chocolate powder sold only in the US.', 'For further info: http://t.co/FvWc7mUr']
# [('@', 'JJ'), ('wmur9', 'NN'), ('we', 'PRP'), ('have', 'VBP'), ('voluntarily', 'RB'), ('recalled', 'VBN'), ('limited', 'JJ'), ('amount', 'NN'), ('of', 'IN'), ('nesquik', 'JJ'), ('chocolate', 'NN'), ('powder', 'NN'), ('sold', 'VBN'), ('only', 'RB'), ('in', 'IN'), ('the', 'DT'), ('us', 'PRP'), ('.', '.')]
#
#
# ["Barclays Wealth looks at the current state of Guernsey's finance community http://ow.ly/Djqj"]
# [('barclays', 'NNS'), ('wealth', 'VBP'), ('look', 'NN'), ('at', 'IN'), ('the', 'DT'), ('current', 'JJ'), ('state', 'NN'), ('of', 'IN'), ('guernsey', 'NN'), ("'s", 'POS'), ('finance', 'NN'), ('community', 'NN'), ('urlplaceholder', 'NN')]
#
#
# ['@twinklesantos Our #Nestle NAN H.A.', '1 Gold infant formula is safe.', 'You can read more here:  http://t.co/OsLjuDg1']
# [('@', 'NN'), ('twinklesantos', 'VBZ'), ('our', 'PRP$'), ('#', '#'), ('nestle', 'JJ'), ('nan', 'JJ'), ('h.a', 'NN'), ('.', '.')]
#
#
# ['Barclays Wealth and Investment Management win at the European Contact Centre and Customer Service Awards']
# [('barclays', 'NNS'), ('wealth', 'NN'), ('and', 'CC'), ('investment', 'NN'), ('management', 'NN'), ('win', 'NN'), ('at', 'IN'), ('the', 'DT'), ('european', 'JJ'), ('contact', 'NN'), ('centre', 'NN'), ('and', 'CC'), ('customer', 'NN'), ('service', 'NN'), ('awards', 'NNS')]
#
#
# ['Exclusive - Goldman to begin fresh round of job cuts: sources:  http://t.co/uEb2KLLPXs #Citigroup #BRK']
# [('exclusive', 'JJ'), ('-', ':'), ('goldman', 'NN'), ('to', 'TO'), ('begin', 'VB'), ('fresh', 'JJ'), ('round', 'NN'), ('of', 'IN'), ('job', 'NN'), ('cut', 'NN'), (':', ':'), ('source', 'NN'), (':', ':'), ('urlplaceholder', 'JJ'), ('#', '#'), ('citigroup', 'NN'), ('#', '#'), ('brk', 'NN')]
#
#
# ['Inheritors feel stronger responsibility for philanthropy than entrepreneurs.', 'Wealth Insights Volume 17: Origins and Legacy...']
# [('inheritors', 'NNS'), ('feel', 'VBP'), ('stronger', 'JJR'), ('responsibility', 'NN'), ('for', 'IN'), ('philanthropy', 'NN'), ('than', 'IN'), ('entrepreneur', 'NN'), ('.', '.')]
#
#
# ['Dr. Freda Lewis-Hall, Chief Medical Officer, comments on U.S.', 'Surgeon General\x89Ûªs report #SGR50 on smoking &amp  health http://t.co/8JA63vhGBL']
# [('dr.', 'JJ'), ('freda', 'NN'), ('lewis-hall', 'NN'), (',', ','), ('chief', 'JJ'), ('medical', 'JJ'), ('officer', 'NN'), (',', ','), ('comment', 'NN'), ('on', 'IN'), ('u.s', 'NN'), ('.', '.')]
#
#
# ['Jamaica, Belize &amp; Suriname earn Citi Microentrepreneurship Awards Ì¢\x89âÂ\x89ÛÏ supporting ideas from ambition to achievement!', 'http://t.co/l1876FKjAW']
# [('jamaica', 'NN'), (',', ','), ('belize', 'VB'), ('&', 'CC'), ('amp', 'VB'), (';', ':'), ('suriname', 'NN'), ('earn', 'VBP'), ('citi', 'JJ'), ('microentrepreneurship', 'NN'), ('awards', 'NNS'), ('ì¢\x89ââ\x89ûï', 'VBP'), ('supporting', 'VBG'), ('idea', 'NN'), ('from', 'IN'), ('ambition', 'NN'), ('to', 'TO'), ('achievement', 'NN'), ('!', '.')]
#
#
# ["Our #Maggi 'cooking caravans' have gone on the road in Africa to raise awareness about micronutrient deficiency.", 'http://t.co/C16S6n0b']
# [('our', 'PRP$'), ('#', '#'), ('maggi', 'NN'), ("'cooking", 'VBG'), ('caravan', 'NN'), ("'", "''"), ('have', 'VBP'), ('gone', 'VBN'), ('on', 'IN'), ('the', 'DT'), ('road', 'NN'), ('in', 'IN'), ('africa', 'NN'), ('to', 'TO'), ('raise', 'VB'), ('awareness', 'NN'), ('about', 'IN'), ('micronutrient', 'JJ'), ('deficiency', 'NN'), ('.', '.')]
#
#
# ['MerckEngage\x89Ûªs new Guide to Health Insurance can help you better understand your options.', 'Learn more: http://t.co/VGw3IxFWU0']
# [('merckengage\x89ûªs', 'JJ'), ('new', 'JJ'), ('guide', 'NN'), ('to', 'TO'), ('health', 'NN'), ('insurance', 'NN'), ('can', 'MD'), ('help', 'VB'), ('you', 'PRP'), ('better', 'JJR'), ('understand', 'VB'), ('your', 'PRP$'), ('option', 'NN'), ('.', '.')]
#
#
# ['What are you like?', 'Read this months @VanityFair for a profile of our #BehaviouralFinance team']
# [('what', 'WP'), ('are', 'VBP'), ('you', 'PRP'), ('like', 'IN'), ('?', '.')]
#
#
# Labels: ['Action' 'Dialogue' 'Information']
# Confusion Matrix:
#  [[100   1  30]
#  [  0  20   8]
#  [  8   0 434]]
# Accuracy: 0.9217970049916805
